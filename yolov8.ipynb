# %% [markdown]
# <a href="https://colab.research.google.com/github/MAtif0306/Machine-learning/blob/main/yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.4/605.4 kB 20.0 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:01<00:00, 34.9MB/s]

# %%
from zipfile import ZipFile
filename = "new.zip"
with ZipFile(filename,'r')as zip:
  zip.extractall()
  print('done')
# Out:
# done

# %%
# !touch data.yaml

# %%
model.train(data = "/content/data.yaml" , epochs = 5)
# Out:
# Ultralytics YOLOv8.0.136 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
infer = YOLO("/content/runs/detect/train4/weights/best.pt")

# %%
infer.predict("/content/new/train/images", save = True , save_txt = True)
# Out:
# image 1/60 /content/new/train/images/jack sparrow_10.jpeg: 384x640 1 jack_sparrow, 75.9ms
# image 2/60 /content/new/train/images/jack sparrow_11.jpeg: 640x512 1 jack_sparrow, 67.1ms
# image 3/60 /content/new/train/images/jack sparrow_111.jpeg: 384x640 1 jack_sparrow, 26.5ms
# image 4/60 /content/new/train/images/jack sparrow_112.jpeg: 640x416 1 jack_sparrow, 67.0ms
# image 5/60 /content/new/train/images/jack sparrow_12.jpeg: 480x640 1 jack_sparrow, 65.4ms
# image 6/60 /content/new/train/images/jack sparrow_122.jpeg: 448x640 1 jack_sparrow, 67.1ms
# image 7/60 /content/new/train/images/jack sparrow_123.jpeg: 640x448 1 jack_sparrow, 70.2ms
# image 8/60 /content/new/train/images/jack sparrow_126.jpeg: 640x640 1 jack_sparrow, 38.0ms
# image 9/60 /content/new/train/images/jack sparrow_127.jpeg: 384x640 1 jack_sparrow, 27.0ms
# image 10/60 /content/new/train/images/jack sparrow_13.jpeg: 384x640 1 jack_sparrow, 26.1ms
# ...

# %%
# !yolo detect predict model='/content/runs/detect/train4/weights/best.pt' source='/content/video.mp4'
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-43-be2cde566778> in <cell line: 1>()
# ----> 1 get_ipython().system("yolo detect predict model='/content/runs/detect/train4/weights/best.pt' source='/content/video.mp4'")
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     451   # is expected to call this function, thus adding one level of nesting to the
#     452   # stack.
# --> 453   result = _run_command(
# ...
