# %% [markdown]
# <a href="https://colab.research.google.com/github/MAtif0306/Machine-learning/blob/main/yolovvv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.4/605.4 kB 23.5 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:01<00:00, 47.3MB/s]

# %%
from zipfile import ZipFile
filename = "new.zip"
with ZipFile(filename,'r')as zip:
  zip.extractall()
  print('done')
# Out:
# done

# %%
# !touch data.yaml

# %%
model.train(data = "/content/data.yaml" , epochs = 5)
# Out:
# Ultralytics YOLOv8.0.136 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
infer = YOLO("/content/runs/detect/train3/weights/best.pt")

# %%
infer.predict("/content/new/train/images", save = True , save_txt = True)
# Out:
# image 1/60 /content/new/train/images/jack sparrow_10.jpeg: 384x640 1 jack_sparrow, 171.5ms
# image 2/60 /content/new/train/images/jack sparrow_11.jpeg: 640x512 1 jack_sparrow, 185.9ms
# image 3/60 /content/new/train/images/jack sparrow_111.jpeg: 384x640 1 jack_sparrow, 27.0ms
# image 4/60 /content/new/train/images/jack sparrow_112.jpeg: 640x416 1 jack_sparrow, 135.5ms
# image 5/60 /content/new/train/images/jack sparrow_12.jpeg: 480x640 1 jack_sparrow, 108.8ms
# image 6/60 /content/new/train/images/jack sparrow_122.jpeg: 448x640 1 jack_sparrow, 166.5ms
# image 7/60 /content/new/train/images/jack sparrow_123.jpeg: 640x448 1 jack_sparrow, 218.1ms
# image 8/60 /content/new/train/images/jack sparrow_126.jpeg: 640x640 1 jack_sparrow, 46.3ms
# image 9/60 /content/new/train/images/jack sparrow_127.jpeg: 384x640 1 jack_sparrow, 56.3ms
# image 10/60 /content/new/train/images/jack sparrow_13.jpeg: 384x640 1 jack_sparrow, 33.9ms
# ...

# %%
infer.predict("/content/video.mp4", save = True , save_txt = True)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1247) /content/video.mp4: 640x640 (no detections), 38.1ms
# video 1/1 (2/1247) /content/video.mp4: 640x640 (no detections), 36.9ms
# video 1/1 (3/1247) /content/video.mp4: 640x640 (no detections), 37.0ms
# video 1/1 (4/1247) /content/video.mp4: 640x640 (no detections), 29.0ms
# video 1/1 (5/1247) /content/video.mp4: 640x640 (no detections), 27.8ms
# video 1/1 (6/1247) /content/video.mp4: 640x640 (no detections), 27.6ms
# ...
